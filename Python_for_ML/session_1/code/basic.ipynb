# %%
Name="Ahmed"
Age=20
Course="Python"
print(f"My Name is {Name} and my age is {Age} and course name is {Course}")
# Out:
# My Name is Ahmed and my age is 20 and course name is Python

# %%
x="DEPI"
x[0:2:1]
# Out:
# 'DE'

# %%
name="depi learning"
print(name.capitalize())

# %%
print("welcome to depi \"machine learning course\"")
# Out:
# welcome to depi "machine learning course"

# %%
x=[1,2,3]
type(x)
# Out:
# list

# %%
x=(2,"jdfjdhcj",(2,7))
x[1]
# Out:
# 'jdfjdhcj'

# %%
list_one=["depi","learning","ai"]
list_one.append("d")
list_one
# Out:
# ['depi', 'learning', 'ai', 'd']

# %%
list_one.insert(0,"data")
list_one
# Out:
# ['data', 'data', 'depi', 'learning', 'ai']

# %%
list_1=[1,2,3]
list_2=[4,5,6]
list_1.extend(list_2)
list_1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_new=["depi","learning","python"]
list_new.remove("depi")
list_new
# Out:
# ['learning', 'python']

# %%
list_1=[1,2,3]
list_2=[4,5,6]
list_3=[7,8,9]
matrix=[list_1,list_2,list_3]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
my_list=["one","two","three",4,5]
my_list*2
# Out:
# ['one', 'two', 'three', 4, 5, 'one', 'two', 'three', 4, 5]

# %%
name=input("pls enter your name")
id=input("enter your id")
print(f"my name is {name} , my id is{id}")
# Out:
# my name is Ahmed , my id is9384

# %%
input_list=["depi","learning","python"]
item =input("enter item in the list")
input_list.remove(item)
print(f"output list={input_list}")
# Out:
# output list=['learning', 'python']

# %%
my_list=[1,2,3,4,4]
index_val= my_list.count(4)
index_val
# Out:
# 2

# %%
list_sort=[3,2,4,7,8,5,1,0]
list_sort.sort()
list_sort
# Out:
# [0, 1, 2, 3, 4, 5, 7, 8]

# %%
list_sort.reverse()
list_sort
# Out:
# [8, 7, 5, 4, 3, 2, 1, 0]

# %%
list_sort.clear()
list_sort
# Out:
# []

# %%
name="depi"
tuple(name)
# Out:
# ('d', 'e', 'p', 'i')

# %%
set_1={"depi","learning"}
set_1
# Out:
# {'depi', 'learning'}

# %%
color={"red","green","blue"}
color.discard("blue")
color
# Out:
# {'green', 'red'}

# %%
a={1,2,3}
b={3,4,5}
print(a.union (b))
# Out:
# {1, 2, 3, 4, 5}

# %%
dict_1={"key_1":12}
type(dict_1)
dict_1["key_1"]="depi"
dict_1
# Out:
# {'key_1': 'depi'}

# %%
10%4
# Out:
# 2

# %%
num_1=float(input("enter num1"))
num_2=float(input("enter num2"))
print(f"num1+num2={num_1+num_2}")
print(f"num1 - num ={num_1-num_2}")
print(f"num1/num2={num_1/num_2}")
print(f" multi:{num_1*num_2}")
# Out:
# num1+num2=15.0
# num1 - num =5.0
# num1/num2=2.0
#  multi:50.0

# %%
a=200
b=33
if b>a:
    print("b is greater than a")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %%
x=5
y=10
if x>0 and y>0:
    print("positive numbers")
# Out:
# positive numbers

# %%
x=5
result="Even" if x%2==0 else"odd"
result
# Out:
# 'odd'

# %%
is_sunny=True
tem=25
if is_sunny:
    print("sunny day")

# %%
degree=int(input("Enter your degree"))
if  0<=degree<= 100:
    if 90<= degree<=100:
        grade='A'
    elif 80<=degree<=90:
        print("B")

    else:
        print("Enter degree between 0 and 100")
# Out:
# B

# %%
for i in range(6):
    if i==3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
