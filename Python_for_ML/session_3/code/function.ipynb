# %%
def user_info(name="test",age=20):
    """
    this function take name and age from user and return again
    :param_1 : take the name of user from input user interface
    type param_1 : str
    :param_2 : take the age of user from input user interface
    type param_2 : int

    return : this func will print the name and the age
    return type: str, int
    """
    return f"my name is {name}, my age is {age}"

# %%
user_info()
# Out:
# 'my name is test, my age is 20'

# %%
def user_info(*name):
    """
    
    """
    print(name)
    print(type(name))

# %%
user_info("depi","python",3,5,4,True,[1,2,3])
# Out:
# ('depi', 'python', 3, 5, 4, True, [1, 2, 3])
# <class 'tuple'>

# %%
def user_info(**name):
    """
    
    """
    print(name)
    print(type(name))

# %%
user_info(key_1=10.5,key_2=2)
# Out:
# {'key_1': 10.5, 'key_2': 2}
# <class 'dict'>

# %%
result=lambda x : x + 10
print(type(result))
# Out:
# <class 'function'>

# %%
func_name= lambda x,y,z:x+y*z
print(func_name(5,10,2))
# Out:
# 25

# %%
x=20
def  fun(x):
    print("inside : ",x)
fun(3) 
print("outside : ",x)
# Out:
# inside :  3
# outside :  20

# %%
x="global"
def outer_fun():
    x="outer_local"
    def inner_fun():
        global x
        x="changed"
        print("inside inner func ",x)
    inner_fun()
    print("inside outer fun:",x)
outer_fun()
print("outside any func:",x)
# Out:
# inside inner func  changed
# inside outer fun: outer_local
# outside any func: changed

# %%
x=int(input())
y=int(input())
try:
    x/y
except Exception as e:
    print(e)   
finally:
    print("Done!")
# Out:
# division by zero
# Done!

# %%
from random import randint,random
random()
# Out:
# 0.3024543969894269

# %%
import os
base_dire="E:/DEBI-ONL4_AIS2_S2/DEBI-ONL4_AIS2_S2/Python_for_ML/session_3/file_handle"
type(base_dire)
# Out:
# str

# %%
file_names=os.listdir(base_dire)
type(file_names)
file_names
# Out:
# ['test.txt']

# %%
base_dire2="./tem_dire"
file_name="txt_1.txt"
file_path=os.path.join(base_dire2,file_name)
file_path
# Out:
# './tem_dire\\txt_1.txt'

# %%
import os
dir="Python_for_ML/session_3/file_handle/test"
if not os.path.exists(dir):
    os.makedirs(dir)
for i in range(20):
    inner_path=os.path.join(dir,"dir_"+str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)
