# %%
def factorial_1(num):
    if num==0:
        return 1
    if num==1:
        return 1
    return num*factorial_1(num-1)

# %%
factorial_1(5)
# Out:
# 120

# %%
def is_prime(num):
    for i in range(2,num):
        if num%i==0:
            return False
    return True

# %%
is_prime(2)
# Out:
# True

# %%
import random
length=8
characters="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
password=""
for _ in range(length):
    password+= random.choice(characters)
print(f"Generate_password:{password}")
# Out:
# Generate_password:@ixgYc4t

# %%
import random
def generate_password(length:int):
    characters="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password=""
    for _ in range(length):
      password+= random.choice(characters)
    return f"Generate_password:{password}"

# %%
generate_password(15)
# Out:
# 'Generate_password:VaZ@UMzfZW042q$'

# %%
from gen_code import generate_password

generate_password(9)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from gen_code import generate_password
#       3 generate_password(9)
#
# ModuleNotFoundError: No module named 'gen_code'
