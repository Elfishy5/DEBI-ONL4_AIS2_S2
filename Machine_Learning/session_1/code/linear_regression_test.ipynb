# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4])
y = np.array([2,2.8,3.6,4.5])

# %%
w = 0
b = 0
alpha = 0.01
num_iteration = 20

# %%
sse_values = []

for i in range(num_iteration):
    y_hat = w * x + b

    D_w = 2/4 * np.sum((y_hat - y) * x)
    D_b = 2/4 * np.sum(y_hat - y)

    w -= alpha * D_w
    b -= alpha * D_b

    sse = (np.sum((y_hat - y)**2))
    sse_values.append(sse)

    if (i+1) % 20 == 0 :
        print(f"iteration {i+1} , sse : {sse}")
# Out:
# iteration 20 , sse : 0.3228405479183226

# %%
print(f"Optimized param : slope = {w} , bais = {b}")
# Out:
# Optimized param : slope = 1.0638929640668833 , bais = 0.45992288642023754

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(range(num_iteration) , sse_values , label = "sse")
plt.xlabel("Iteration")
plt.ylabel("SSE")
plt.title("SSE over Iteration")
plt.legend()
plt.subplot(1,2,2)
plt.scatter(x,y, color = "blue" , label = "Data point")
plt.plot(x , w * x + b , color = "red" , label = "Regression line")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regression fit line")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y = w * x + b
y
# Out:
# array([1.52381585, 2.58770881, 3.65160178, 4.71549474])

# %%
x_new = int(input("please enter new value"))
y = w * x_new +b
y
# Out:
# np.float64(5.779387706754654)

# %%
from sklearn.linear_model import LinearRegression
L1 = LinearRegression()
L1.fit()
