# %% [markdown]
# # Imports

# %% [markdown]
# - **Replace Null Values in Age column**

# %% [markdown]
# ### 4- Handle Outliers

# %% [markdown]
# - **Check for Outliers**

# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("E:/Alsayad Electronics/Downloads/train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Name', 'Ticket'], axis = 1, inplace= True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %% [markdown]
# ## Chk datatype

# %%
dtypes = df.dtypes
n_uniq = df.nunique()
pd.DataFrame({"Dtype":dtypes, "Num_Uniqe":n_uniq}).T
# Out:
#           Survived Pclass  Sex      Age  SibSp  Parch     Fare Cabin Embarked
# Dtype        int64  int64  str  float64  int64  int64  float64   str      str
# Num_Uniqe        2      3    2       88      7      7      248   147        3

# %%
def chk_types(data):
    dtypes = df.dtypes
    n_uniq = df.nunique()
    
    return pd.DataFrame({"Dtype":dtypes, "Num_Uniqe":n_uniq}).T

# %%
def chk_types_table(data):
    return pd.DataFrame({
        "Dtype": data.dtypes,
        "Num_Unique": data.nunique()
    }).T

# %%
chk_types_table(df)
# Out:
#            Survived Pclass  Sex      Age  SibSp  Parch     Fare Cabin Embarked
# Dtype         int64  int64  str  float64  int64  int64  float64   str      str
# Num_Unique        2      3    2       88      7      7      248   147        3

# %%
cols = ['Pclass',
        'Survived',
        'Sex',
        'SibSp',
        'Parch',
        'Embarked']
df[cols] = df[cols].astype('category')

# %%
chk_types(df)
# Out:
#            Survived    Pclass       Sex      Age     SibSp     Parch     Fare  \
# Dtype      category  category  category  float64  category  category  float64
# Num_Uniqe         2         3         2       88         7         7      248
#
#           Cabin  Embarked
# Dtype       str  category
# Num_Uniqe   147         3

# %%
df.shape[0]
# Out:
# 891

# %%
null = df.isnull().sum()
ratio = (null/ df.shape[0])*100
pd.DataFrame({"Null":null, "ratio % ":ratio}).T
# Out:
#           Survived  Pclass  Sex        Age  SibSp  Parch  Fare       Cabin  \
# Null           0.0     0.0  0.0  177.00000    0.0    0.0   0.0  687.000000
# ratio %        0.0     0.0  0.0   19.86532    0.0    0.0   0.0   77.104377
#
#           Embarked
# Null      2.000000
# ratio %   0.224467

# %%
median_1 = df['Age'].median()
df['Age'].fillna(median_1, inplace=True)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.dropna(subset=['Embarked'], inplace= True)
df = df.drop("Cabin", axis=1)

# %%
null = df.isnull().sum()
ratio = (null/ df.shape[0])*100
pd.DataFrame({"Null":null, "ratio % ":ratio}).T
# Out:
#           Survived  Pclass  Sex         Age  SibSp  Parch  Fare  Embarked
# Null           0.0     0.0  0.0  177.000000    0.0    0.0   0.0       0.0
# ratio %        0.0     0.0  0.0   19.910011    0.0    0.0   0.0       0.0

# %%
num_cols = df.select_dtypes('number').columns
plt.figure(figsize=(8,1))
for i , col in enumerate(num_cols):
    plt.subplot(1,2, i+1)
    sns.boxplot(df[col], orient="h")
    plt.title(f"{col} Boxplot")

# %%
def outliers_change(num_cols):
    for col in num_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_fence = Q1 -  1.5*IQR
        upper_fence = Q3 +  1.5*IQR
        # print(lower_fence)
        lower_outliers = df[df[col]< lower_fence][col].values
        upper_outliers = df[df[col]> upper_fence][col].values
        
        df[col].replace(lower_outliers, lower_fence, inplace=True)
        df[col].replace(upper_outliers, upper_fence, inplace=True)

    # upper_outliers =

# %%
num_cols = df.select_dtypes('number').columns
plt.figure(figsize=(8,1))
for i , col in enumerate(num_cols):
    plt.subplot(1,2, i+1)
    sns.boxplot(df[col], orient="h")
    plt.title(f"{col} Boxplot")

# %%
df.duplicated().sum()
# Out:
# np.int64(111)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
px.histogram(df , x = 'Survived' , color = 'Sex' , title = '<b> Survived based on gender')

# %%
plt.figure(figsize=(9,2))
for i , col in enumerate(num_cols):
    plt.subplot(1, 2, i + 1 )
    plt.hist(df[col], edgecolor = 'black')
    plt.title(f"{col} hist_graph")
plt.show()

# %%
cat_cols = df.select_dtypes('category').columns

# %%
plt.figure(figsize=(14,4))
for i , col in enumerate(cat_cols):
    plt.subplot(2, 3, i + 1 )
    sns.countplot(x = col, data = df)
    plt.title(f"{col} Distribution_graph")
    plt.subplots_adjust(hspace = .8, wspace=.3)
plt.show()

# %%
unique = df['Survived'].value_counts()
count = unique.values
categories = unique.index

# %%
plt.figure(figsize=(9,4))
for i, col in enumerate(cat_cols) :
    plt.subplot(2 , 3 , i + 1)
    unique = df[col].value_counts()
    count = unique.values
    categories = unique.index
    plt.pie(count,labels= categories,startangle= 140 , autopct = "%1.1f%%")
    plt.title(f"{col} Pie graph")
plt.subplots_adjust(hspace=.8 , wspace=.3)
plt.show()

# %%
plt.figure(figsize=(2,3))
plt.scatter(df['Age'] , df['Fare'])

# %%
sns.pairplot(df)

# %%
corr = df[['Age' , 'Fare']].corr()
corr
# Out:
#            Age      Fare
# Age   1.000000  0.090985
# Fare  0.090985  1.000000

# %%
corr = df.select_dtypes(include="number").corr()
corr
# Out:
#            Age      Fare
# Age   1.000000  0.090985
# Fare  0.090985  1.000000

# %%
agg = df.pivot_table(index= 'Survived', columns='Sex', values='Age', aggfunc= len)
agg
# Out:
# Sex       female  male
# Survived
# 0             76   382
# 1            214   106

# %%
plt.figure(figsize=(2,2))
agg = df.pivot_table(index= 'Survived', columns='Sex', values='Age', aggfunc= len)
sns.heatmap(agg)
plt.show()

# %%
x = df.drop('Survived', axis=1)
y= df['Survived']

# %%
x
# Out:
#     Pclass     Sex   Age SibSp Parch     Fare Embarked
# 0        3    male  22.0     1     0   7.2500        S
# 1        1  female  38.0     1     0  71.2833        C
# 2        3  female  26.0     0     0   7.9250        S
# 3        1  female  35.0     1     0  53.1000        S
# 4        3    male  35.0     0     0   8.0500        S
# ..     ...     ...   ...   ...   ...      ...      ...
# 885      3  female  39.0     0     5  29.1250        Q
# 887      1  female  19.0     0     0  30.0000        S
# 888      3  female   NaN     1     2  23.4500        S
# 889      1    male  26.0     0     0  30.0000        C
# 890      3    male  32.0     0     0   7.7500        Q
#
# [778 rows x 7 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 778, dtype: category
# Categories (2, int64): [0, 1]

# %%
from sklearn.preprocessing import MinMaxScaler
num_cols = x.select_dtypes('number').columns
scaler = MinMaxScaler()
scaler.fit(x[num_cols])
x[num_cols] = scaler.transform(x[num_cols])

# Previewing x
x
# Out:
#     Pclass     Sex       Age SibSp Parch      Fare Embarked
# 0        3    male  0.271174     1     0  0.014151        S
# 1        1  female  0.472229     1     0  0.139136        C
# 2        3  female  0.321438     0     0  0.015469        S
# 3        1  female  0.434531     1     0  0.103644        S
# 4        3    male  0.434531     0     0  0.015713        S
# ..     ...     ...       ...   ...   ...       ...      ...
# 885      3  female  0.484795     0     5  0.056848        Q
# 887      1  female  0.233476     0     0  0.058556        S
# 888      3  female       NaN     1     2  0.045771        S
# 889      1    male  0.321438     0     0  0.058556        C
# 890      3    male  0.396833     0     0  0.015127        Q
#
# [778 rows x 7 columns]

# %%
str_cols = ['Sex', 'Embarked']

from category_encoders import OneHotEncoder

encoder = OneHotEncoder(cols=str_cols, drop_invariant=True)
x = encoder.fit_transform(x)

# Final preview of encoded dataframe
x
# Out:
#     Pclass  Sex_1  Sex_2       Age SibSp Parch      Fare  Embarked_1  \
# 0        3      1      0  0.271174     1     0  0.014151           1
# 1        1      0      1  0.472229     1     0  0.139136           0
# 2        3      0      1  0.321438     0     0  0.015469           1
# 3        1      0      1  0.434531     1     0  0.103644           1
# 4        3      1      0  0.434531     0     0  0.015713           1
# ..     ...    ...    ...       ...   ...   ...       ...         ...
# 885      3      0      1  0.484795     0     5  0.056848           0
# 887      1      0      1  0.233476     0     0  0.058556           1
# 888      3      0      1       NaN     1     2  0.045771           1
# 889      1      1      0  0.321438     0     0  0.058556           0
# 890      3      1      0  0.396833     0     0  0.015127           0
#
#      Embarked_2  Embarked_3
# 0             0           0
# 1             1           0
# 2             0           0
# 3             0           0
# 4             0           0
# ..          ...         ...
# 885           0           1
# 887           0           0
# 888           0           0
# 889           1           0
# 890           0           1
#
# [778 rows x 10 columns]

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
fig = px.pie(df , names='Survived' ,
       title = '<b>Survived distribution </b>' ,
       color_discrete_sequence= px.colors.qualitative.Pastel,
       hole = 0.4
       )
fig.show()

# %%
fig = px.pie(df , names='Survived' ,
       title = '<b>                          Survived distribution </b>' ,
       color_discrete_map = {0 : 'blue',
                             1 : 'red'},
       category_orders={'Survived ': ['1', '0']},                      
       hole = 0.7
       )
fig.show()

# %%
fig = px.pie(df , names='Survived' ,
       title = '<b>Survived distribution </b>' ,
       color_discrete_sequence= px.colors.qualitative.Pastel,
       hole = 0.4
       )
fig.update_layout(annotations = [dict(text = 'Survived ',font_size= 20 , x=0.5 ,y=0.5 , showarrow = False)])
fig.show()

# %%
px.histogram(df , x = 'Survived' , color = 'Sex' , title = '<b> Survived based on gender' , barmode = 'group')
#fig.update_layout(width = 500 , height = 400 , bargap = 0.4)

# %%
import plotly.subplots as sp
import plotly.graph_objects as go
fig = sp.make_subplots(rows = 1 , cols = len(num_cols) , subplot_titles= num_cols)
for i , col in enumerate(num_cols) :
    fig.add_trace(go.Histogram(x = df[col], name= col , marker= dict(line= dict(color= 'black', width= 1)))
                  , row = 1 , col = i + 1) 

fig.show()

# %%
# %pip install dash
# Out:
# Collecting dash
#   Downloading dash-4.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting Flask<3.2,>=1.0.4 (from dash)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.2 (from dash)
#   Downloading werkzeug-3.1.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: plotly>=5.0.0 in e:\debi-onl4_ais2_s2\debi-onl4_ais2_s2\env\lib\site-packages (from dash) (6.5.2)
# Collecting importlib-metadata (from dash)
#   Downloading importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in e:\debi-onl4_ais2_s2\debi-onl4_ais2_s2\env\lib\site-packages (from dash) (4.15.0)
# Collecting requests (from dash)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in e:\debi-onl4_ais2_s2\debi-onl4_ais2_s2\env\lib\site-packages (from dash) (1.6.0)
# Collecting setuptools (from dash)
#   Downloading setuptools-80.10.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting blinker>=1.9.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from Flask<3.2,>=1.0.4->dash)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from Flask<3.2,>=1.0.4->dash)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from Flask<3.2,>=1.0.4->dash)
#   Downloading markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: colorama in e:\debi-onl4_ais2_s2\debi-onl4_ais2_s2\env\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in e:\debi-onl4_ais2_s2\debi-onl4_ais2_s2\env\lib\site-packages (from plotly>=5.0.0->dash) (2.16.0)
# Requirement already satisfied: packaging in e:\debi-onl4_ais2_s2\debi-onl4_ais2_s2\env\lib\site-packages (from plotly>=5.0.0->dash) (25.0)
# Collecting zipp>=3.20 (from importlib-metadata->dash)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests->dash)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->dash)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->dash)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests->dash)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Downloading dash-4.0.0-py3-none-any.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 1.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 0.8/7.2 MB 1.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/7.2 MB 1.5 MB/s eta 0:00:05
#    -------- ------------------------------- 1.6/7.2 MB 1.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.8/7.2 MB 1.5 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.1/7.2 MB 1.6 MB/s eta 0:00:04
#    ------------- -------------------------- 2.4/7.2 MB 1.4 MB/s eta 0:00:04
#    -------------- ------------------------- 2.6/7.2 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 2.9/7.2 MB 1.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.1/7.2 MB 1.5 MB/s eta 0:00:03
#    ------------------ --------------------- 3.4/7.2 MB 1.4 MB/s eta 0:00:03
#    -------------------- ------------------- 3.7/7.2 MB 1.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.2/7.2 MB 1.5 MB/s eta 0:00:03
#    ------------------------ --------------- 4.5/7.2 MB 1.5 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.2 MB 1.5 MB/s eta 0:00:02
#    --------------------------- ------------ 5.0/7.2 MB 1.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.2/7.2 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 5.8/7.2 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.0/7.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 1.5 MB/s  0:00:04
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading werkzeug-3.1.5-py3-none-any.whl (225 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Downloading importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading setuptools-80.10.2-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 762.0 kB/s eta 0:00:01
#    ------------------- -------------------- 0.5/1.1 MB 762.0 kB/s eta 0:00:01
#    ----------------------------- ---------- 0.8/1.1 MB 860.9 kB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 900.2 kB/s  0:00:01
# Installing collected packages: zipp, urllib3, setuptools, retrying, markupsafe, itsdangerous, idna, click, charset_normalizer, certifi, blinker, Werkzeug, requests, jinja2, importlib-metadata, Flask, dash
#
#    ----------------------------------------  0/17 [zipp]
#    -- -------------------------------------  1/17 [urllib3]
#    -- -------------------------------------  1/17 [urllib3]
#    -- -------------------------------------  1/17 [urllib3]
#    -- -------------------------------------  1/17 [urllib3]
#    -- -------------------------------------  1/17 [urllib3]
#    -- -------------------------------------  1/17 [urllib3]
#    -- -------------------------------------  1/17 [urllib3]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    ---- -----------------------------------  2/17 [setuptools]
#    --------- ------------------------------  4/17 [markupsafe]
#    --------- ------------------------------  4/17 [markupsafe]
#    --------- ------------------------------  4/17 [markupsafe]
#    ----------- ----------------------------  5/17 [itsdangerous]
#    -------------- -------------------------  6/17 [idna]
#    -------------- -------------------------  6/17 [idna]
#    -------------- -------------------------  6/17 [idna]
#    ---------------- -----------------------  7/17 [click]
#    ---------------- -----------------------  7/17 [click]
#    ---------------- -----------------------  7/17 [click]
#    ---------------- -----------------------  7/17 [click]
#    ------------------ ---------------------  8/17 [charset_normalizer]
#    ------------------ ---------------------  8/17 [charset_normalizer]
#    ------------------ ---------------------  8/17 [charset_normalizer]
#    ------------------ ---------------------  8/17 [charset_normalizer]
#    ------------------ ---------------------  8/17 [charset_normalizer]
#    ------------------ ---------------------  8/17 [charset_normalizer]
#    --------------------- ------------------  9/17 [certifi]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ------------------------- -------------- 11/17 [Werkzeug]
#    ---------------------------- ----------- 12/17 [requests]
#    ---------------------------- ----------- 12/17 [requests]
#    ---------------------------- ----------- 12/17 [requests]
#    ---------------------------- ----------- 12/17 [requests]
#    ------------------------------ --------- 13/17 [jinja2]
#    ------------------------------ --------- 13/17 [jinja2]
#    ------------------------------ --------- 13/17 [jinja2]
#    ------------------------------ --------- 13/17 [jinja2]
#    ------------------------------ --------- 13/17 [jinja2]
#    ------------------------------ --------- 13/17 [jinja2]
#    -------------------------------- ------- 14/17 [importlib-metadata]
#    -------------------------------- ------- 14/17 [importlib-metadata]
#    -------------------------------- ------- 14/17 [importlib-metadata]
#    ----------------------------------- ---- 15/17 [Flask]
#    ----------------------------------- ---- 15/17 [Flask]
#    ----------------------------------- ---- 15/17 [Flask]
#    ----------------------------------- ---- 15/17 [Flask]
#    ----------------------------------- ---- 15/17 [Flask]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ------------------------------------- -- 16/17 [dash]
#    ---------------------------------------- 17/17 [dash]
#
# Successfully installed Flask-3.1.2 Werkzeug-3.1.5 blinker-1.9.0 certifi-2026.1.4 charset_normalizer-3.4.4 click-8.3.1 dash-4.0.0 idna-3.11 importlib-metadata-8.7.1 itsdangerous-2.2.0 jinja2-3.1.6 markupsafe-3.0.3 requests-2.32.5 retrying-1.4.2 setuptools-80.10.2 urllib3-2.6.3 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
